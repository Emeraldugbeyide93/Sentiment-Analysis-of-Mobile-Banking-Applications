# %%
pip install google-play-scraper
# Out:
# Collecting google-play-scraper
#   Downloading google-play-scraper-1.0.3.tar.gz (52 kB)
# Building wheels for collected packages: google-play-scraper
#   Building wheel for google-play-scraper (setup.py): started
#   Building wheel for google-play-scraper (setup.py): finished with status 'done'
#   Created wheel for google-play-scraper: filename=google_play_scraper-1.0.3-py3-none-any.whl size=24394 sha256=f315972c85a7aefe4d39e592851d4383f8542ab0c3b3c7793e2ec601c5d64f66
#   Stored in directory: c:\users\emera\appdata\local\pip\cache\wheels\b0\17\bf\a06f635b5343780c7ec2b554dccc3aa4cf3ead928304088ad5
# Successfully built google-play-scraper
# Installing collected packages: google-play-scraper
# Successfully installed google-play-scraper-1.0.3
# Note: you may need to restart the kernel to use updated packages.

# %%
from google_play_scraper import app

import pandas as pd

import numpy as np

# %%
from google_play_scraper import Sort, reviews_all


uk_reviews = reviews_all(
    'com.barclays.android.barclaysmobilebanking',
    sleep_milliseconds=0, # defaults to 0
    lang='en', # defaults to 'en'
    country='uk', # defaults to 'us'
    sort=Sort.NEWEST, # defaults to Sort.MOST_RELEVANT
)

# %%
df_gr = pd.DataFrame(np.array(uk_reviews),columns=['review'])


df_gr = df_gr.join(pd.DataFrame(df_gr.pop('review').tolist()))


df_gr
# Out:
#                                                  reviewId         userName  \
# 0       gp:AOqpTOFoVIqHJy98McbAqzul8Su5uvCtPbXAOWLuSNo...          GM DODD
# 1       gp:AOqpTOFb6Yku2q1B22BYGtb9WyudP48bubPguJgsKJ-...     Ray Phillips
# 2       gp:AOqpTOGuocQfqXF5KWilhYKgH_44x4I6BUvediUbn09...    Derek Francis
# 3       gp:AOqpTOGIg_GPys9KU572qpMp1OXada3E9ZmUoYK7svR...     David Howker
# 4       gp:AOqpTOGt6r7yM-BfjnoGZ-6LpSxRLcGXfq7E6p42CWl...  Constance Ncube
# ...                                                   ...              ...
# 195656  lg:AOqpTOHK24bXCYI9jGNLn6HPaNQ0X0Qlr2ycrj73k1G...    A Google user
# 195657  lg:AOqpTOFDKn2bBGnZTOFuFqVf_W2CreCsM7qEmF30NlO...    A Google user
# 195658  lg:AOqpTOEbQKjdtgsLqY7OaIeu3B8gjoPwdByf0wNWfcU...    A Google user
# 195659  lg:AOqpTOHaWtQPyJ0wrQnaqNvVMinkLqmRdC3wSgU0Lky...    A Google user
# 195660  lg:AOqpTOGv53xVAsJOje_7T7I3Ek4UFRdg_2puEsjBdaZ...    A Google user
#
#                                                 userImage  \
# 0       https://play-lh.googleusercontent.com/a/AATXAJ...
# 1       https://play-lh.googleusercontent.com/a-/AOh14...
# 2       https://play-lh.googleusercontent.com/a/AATXAJ...
# 3       https://play-lh.googleusercontent.com/a/AATXAJ...
# 4       https://play-lh.googleusercontent.com/a/AATXAJ...
# ...                                                   ...
# 195656  https://play-lh.googleusercontent.com/EGemoI2N...
# 195657  https://play-lh.googleusercontent.com/EGemoI2N...
# 195658  https://play-lh.googleusercontent.com/EGemoI2N...
# 195659  https://play-lh.googleusercontent.com/EGemoI2N...
# 195660  https://play-lh.googleusercontent.com/EGemoI2N...
#
#                                                   content  score  \
# 0        Very good. Easy to use and appears quite secure.      5
# 1       Trying to register for online banking, when I ...      1
# 2       Contactless via mobile phone is worse than poo...      1
# 3                                             Easy to use      5
# 4                 It's easy to use the security is great.      5
# ...                                                   ...    ...
# 195656                             Amazing app thank you!      5
# 195657  Great app now I can see accounts and Barclayca...      5
# 195658  Easy to register, does everything I need, look...      5
# 195659  Simple, slick registration. Great features. Ju...      5
# 195660                                          Excellent      5
#
#         thumbsUpCount reviewCreatedVersion                  at replyContent  \
# 0                   0               2.52.0 2022-02-13 19:09:45         None
# 1                   0               2.52.0 2022-02-13 16:46:20         None
# 2                   0               2.52.0 2022-02-13 16:31:48         None
# 3                   0                 None 2022-02-13 16:06:37         None
# 4                   0                 None 2022-02-13 15:55:38         None
# ...               ...                  ...                 ...          ...
# 195656              0                  1.0 2012-07-06 12:08:39         None
# 195657              0                  1.0 2012-07-06 12:06:51         None
# 195658              0                  1.0 2012-07-06 10:35:10         None
# 195659              0                  1.0 2012-07-06 08:23:44         None
# 195660              1                  1.0 2012-07-06 07:54:32         None
#
#        repliedAt
# 0            NaT
# 1            NaT
# 2            NaT
# 3            NaT
# 4            NaT
# ...          ...
# 195656       NaT
# 195657       NaT
# 195658       NaT
# 195659       NaT
# 195660       NaT
#
# [195661 rows x 10 columns]

# %%
df = df_gr[: 3500]

# %%
df
# Out:
#                                                reviewId         userName  \
# 0     gp:AOqpTOFoVIqHJy98McbAqzul8Su5uvCtPbXAOWLuSNo...          GM DODD
# 1     gp:AOqpTOFb6Yku2q1B22BYGtb9WyudP48bubPguJgsKJ-...     Ray Phillips
# 2     gp:AOqpTOGuocQfqXF5KWilhYKgH_44x4I6BUvediUbn09...    Derek Francis
# 3     gp:AOqpTOGIg_GPys9KU572qpMp1OXada3E9ZmUoYK7svR...     David Howker
# 4     gp:AOqpTOGt6r7yM-BfjnoGZ-6LpSxRLcGXfq7E6p42CWl...  Constance Ncube
# ...                                                 ...              ...
# 3495  gp:AOqpTOGAir2jZsJ9mydTWLp2zaMU-e1Dhq6E8Kf97z6...            Sue L
# 3496  gp:AOqpTOF5Qgixvk3h1BM1hO7ykxzT6h9ZJSmqSSlVJ9k...      Taimur Khan
# 3497  gp:AOqpTOFOwvqFmAZYg1qsI8rPIlVfONtCn_H4at_eA4C...    stephen davey
# 3498  gp:AOqpTOG9sl15VFbO_S6_onkNwxX5RUs86qCzqzA19Fk...       naomi Hunt
# 3499  gp:AOqpTOHunh73yN2iEIEqAQJc1QRC2B5DUAnpN_4C3St...    Simon Couzens
#
#                                               userImage  \
# 0     https://play-lh.googleusercontent.com/a/AATXAJ...
# 1     https://play-lh.googleusercontent.com/a-/AOh14...
# 2     https://play-lh.googleusercontent.com/a/AATXAJ...
# 3     https://play-lh.googleusercontent.com/a/AATXAJ...
# 4     https://play-lh.googleusercontent.com/a/AATXAJ...
# ...                                                 ...
# 3495  https://play-lh.googleusercontent.com/a/AATXAJ...
# 3496  https://play-lh.googleusercontent.com/a-/AOh14...
# 3497  https://play-lh.googleusercontent.com/a/AATXAJ...
# 3498  https://play-lh.googleusercontent.com/a-/AOh14...
# 3499  https://play-lh.googleusercontent.com/a/AATXAJ...
#
#                                                 content  score  thumbsUpCount  \
# 0      Very good. Easy to use and appears quite secure.      5              0
# 1     Trying to register for online banking, when I ...      1              0
# 2     Contactless via mobile phone is worse than poo...      1              0
# 3                                           Easy to use      5              0
# 4               It's easy to use the security is great.      5              0
# ...                                                 ...    ...            ...
# 3495  This a useful app & seems to work securely. Tr...      5              0
# 3496                 Not even close to Monzo experience      1              0
# 3497                                  Very good service      5              0
# 3498  Can't log back in after uninstalling the app i...      4              0
# 3499  May show accounts and allow online banking but...      1              0
#
#      reviewCreatedVersion                  at  \
# 0                  2.52.0 2022-02-13 19:09:45
# 1                  2.52.0 2022-02-13 16:46:20
# 2                  2.52.0 2022-02-13 16:31:48
# 3                    None 2022-02-13 16:06:37
# 4                    None 2022-02-13 15:55:38
# ...                   ...                 ...
# 3495               2.52.0 2022-01-03 06:55:52
# 3496               2.52.0 2022-01-03 06:02:36
# 3497               2.52.0 2022-01-03 05:58:54
# 3498                 None 2022-01-03 03:25:40
# 3499               2.52.0 2022-01-02 23:13:32
#
#                                            replyContent           repliedAt
# 0                                                  None                 NaT
# 1                                                  None                 NaT
# 2                                                  None                 NaT
# 3                                                  None                 NaT
# 4                                                  None                 NaT
# ...                                                 ...                 ...
# 3495                                               None                 NaT
# 3496  Hi Taimur, thanks for reaching out. Sorry to h... 2022-01-24 10:49:18
# 3497                                               None                 NaT
# 3498                                               None                 NaT
# 3499  Hi Simon, thanks for your feedback. If you cli... 2022-01-24 10:47:42
#
# [3500 rows x 10 columns]

# %%
df.to_csv('BarclaysMobileApp3500rows.csv')
